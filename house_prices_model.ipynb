# %%
# Imports
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Carregar o dataset
data = pd.read_csv('/content/drive/MyDrive/Braskem/house_prices.csv')

data.head()
# Out:
#          Area  Quartos  Banheiros      Price
# 0  238.202617        3          3  126877.82
# 1  170.007860        2          2   87197.04
# 2  198.936899        4          1  104976.31
# 3  262.044660        1          1   97078.75
# 4  243.377900        1          2   93673.56

# %%
# Separar as variáveis independes e dependentes
X = data.drop('Price', axis=1)
Y = data['Price']

# %%
X.head()
# Out:
#          Area  Quartos  Banheiros
# 0  238.202617        3          3
# 1  170.007860        2          2
# 2  198.936899        4          1
# 3  262.044660        1          1
# 4  243.377900        1          2

# %%
Y.head()
# Out:
# 0    126877.82
# 1     87197.04
# 2    104976.31
# 3     97078.75
# 4     93673.56
# Name: Price, dtype: float64

# %%
# Dividir os dados em conjuntos de treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Criar e treinar o modelo
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Avaliar o modelo
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 28279431.550708275

# %%
# Salvar o modelo
import joblib

joblib.dump(model, '/content/drive/MyDrive/Braskem/modelo_treinado.pkl')
# Out:
# ['/content/drive/MyDrive/Braskem/modelo_treinado.pkl']
